# %% [markdown]
# <a href="https://colab.research.google.com/github/Azri-Muhsin/practice-building-gpt/blob/main/GPT_Tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ord("h")
# Out:
# 104

# %%
ord("🍻")
# Out:
# 127867

# %%
ord("😀")
# Out:
# 128512

# %%
list("Why am i even doing this 💵💵💵💵".encode("utf-8"))
# Out:
# [87,
#  104,
#  121,
#  32,
#  97,
#  109,
#  32,
#  105,
#  32,
#  101,
#  118,
#  101,
#  110,
#  32,
#  100,
#  111,
#  105,
#  110,
#  103,
#  32,
#  116,
#  104,
#  105,
#  115,
#  32,
#  240,
#  159,
#  146,
#  181,
#  240,
#  159,
#  146,
#  181,
#  240,
#  159,
#  146,
#  181,
#  240,
#  159,
#  146,
#  181]

# %%
list("Why am i even doing this 💵💵💵💵".encode("utf-16"))
# Out:
# [255,
#  254,
#  87,
#  0,
#  104,
#  0,
#  121,
#  0,
#  32,
#  0,
#  97,
#  0,
#  109,
#  0,
#  32,
#  0,
#  105,
#  0,
#  32,
#  0,
#  101,
#  0,
#  118,
#  0,
#  101,
#  0,
#  110,
#  0,
#  32,
#  0,
#  100,
#  0,
#  111,
#  0,
#  105,
#  0,
#  110,
#  0,
#  103,
#  0,
#  32,
#  0,
#  116,
#  0,
#  104,
#  0,
#  105,
#  0,
#  115,
#  0,
#  32,
#  0,
#  61,
#  216,
#  181,
#  220,
#  61,
#  216,
#  181,
#  220,
#  61,
#  216,
#  181,
#  220,
#  61,
#  216,
#  181,
#  220]

# %% [markdown]
# ###**BPE (Byte Pair Encoding Algorithm)**
